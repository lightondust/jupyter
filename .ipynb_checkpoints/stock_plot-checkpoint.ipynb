# %% [markdown]
# # データ可視化

# %% [markdown]
# ## データ取得

# %%
!
from database_sql.py import Database
import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2e319e0c1808> in <module>()
# ----> 1 from database_sql.py import Database
#       2 import datetime
#
# ~\Documents\jupyter\database_sql.py in <module>()
# ----> 1 import pymysql.cursors
#       2
#       3
#       4 class Database():
#       5     """mysqlのqueryをあたえて実行する"""
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
op = DataOperation()

# %%
op.db.sql = "select per from stock.price where date={} and per>0 order by per asc;".format("'2017/12/1'")

# %%
per = op.db.execute()

# %%
print(per)
# Out:
# [{'per': 1.01}, {'per': 1.36}, {'per': 1.67}, {'per': 2.45}, {'per': 2.69}, {'per': 2.98}, {'per': 3.23}, {'per': 3.32}, {'per': 3.38}, {'per': 3.54}, {'per': 3.64}, {'per': 3.74}, {'per': 3.83}, {'per': 3.84}, {'per': 3.97}, {'per': 3.99}, {'per': 4.03}, {'per': 4.05}, {'per': 4.11}, {'per': 4.12}, {'per': 4.18}, {'per': 4.19}, {'per': 4.21}, {'per': 4.25}, {'per': 4.31}, {'per': 4.31}, {'per': 4.38}, {'per': 4.4}, {'per': 4.4}, {'per': 4.44}, {'per': 4.45}, {'per': 4.47}, {'per': 4.61}, {'per': 4.64}, {'per': 4.66}, {'per': 4.67}, {'per': 4.81}, {'per': 4.94}, {'per': 4.97}, {'per': 5.06}, {'per': 5.08}, {'per': 5.11}, {'per': 5.15}, {'per': 5.16}, {'per': 5.27}, {'per': 5.33}, {'per': 5.34}, {'per': 5.37}, {'per': 5.42}, {'per': 5.45}, {'per': 5.47}, {'per': 5.49}, {'per': 5.52}, {'per': 5.56}, {'per': 5.61}, {'per': 5.66}, {'per': 5.68}, {'per': 5.72}, {'per': 5.76}, {'per': 5.79}, {'per': 5.83}, {'per': 5.88}, {'per': 5.89}, {'per': 5.93}, {'per': 5.96}, {'per': 5.97}, {'per': 5
# ...

# %%
per_list = []
for p in per:
    per_list.append(p["per"])

# %%
print(per_list)
# Out:
# [1.01, 1.36, 1.67, 2.45, 2.69, 2.98, 3.23, 3.32, 3.38, 3.54, 3.64, 3.74, 3.83, 3.84, 3.97, 3.99, 4.03, 4.05, 4.11, 4.12, 4.18, 4.19, 4.21, 4.25, 4.31, 4.31, 4.38, 4.4, 4.4, 4.44, 4.45, 4.47, 4.61, 4.64, 4.66, 4.67, 4.81, 4.94, 4.97, 5.06, 5.08, 5.11, 5.15, 5.16, 5.27, 5.33, 5.34, 5.37, 5.42, 5.45, 5.47, 5.49, 5.52, 5.56, 5.61, 5.66, 5.68, 5.72, 5.76, 5.79, 5.83, 5.88, 5.89, 5.93, 5.96, 5.97, 5.99, 5.99, 6.01, 6.02, 6.05, 6.06, 6.07, 6.11, 6.13, 6.15, 6.18, 6.21, 6.21, 6.33, 6.34, 6.34, 6.35, 6.39, 6.44, 6.47, 6.47, 6.49, 6.53, 6.53, 6.54, 6.54, 6.56, 6.59, 6.6, 6.62, 6.62, 6.64, 6.67, 6.68, 6.69, 6.69, 6.71, 6.71, 6.72, 6.72, 6.73, 6.73, 6.75, 6.76, 6.8, 6.81, 6.82, 6.82, 6.83, 6.83, 6.83, 6.87, 6.88, 6.89, 6.9, 6.9, 6.91, 6.91, 6.93, 6.96, 7.02, 7.02, 7.05, 7.06, 7.1, 7.11, 7.11, 7.14, 7.14, 7.15, 7.18, 7.18, 7.2, 7.23, 7.24, 7.25, 7.28, 7.28, 7.29, 7.35, 7.35, 7.36, 7.36, 7.37, 7.38, 7.41, 7.41, 7.44, 7.45, 7.45, 7.48, 7.49, 7.5, 7.5, 7.51, 7.52, 7.52, 7.53, 7.56, 7.58, 7.6, 7.6, 7
# ...

# %%
print(op.get_per(date="2017/12/1"))
# Out:
# [-802.26, -675.74, -566.47, -551.25, -406.34, -363.53, -329.19, -297.76, -296.77, -271.26, -261.11, -259.16, -243.48, -232.89, -213.6, -210.33, -204.44, -191.07, -182.67, -157.08, -151.97, -139.14, -135.97, -131.68, -131.05, -129.31, -124.4, -120.89, -120.78, -111.56, -109.96, -101.7, -101.2, -93.46, -88.08, -88.03, -87.5, -82.85, -82.62, -81.57, -79.51, -76.57, -75.14, -66.12, -65.3, -64.78, -64.03, -62.58, -62.47, -62.37, -59.93, -59.22, -58.71, -57.04, -56.78, -56.61, -55.61, -54.93, -53.39, -53.27, -52.52, -52.01, -51.85, -51.4, -48.86, -48.52, -47.1, -46.89, -45.59, -44.54, -44.41, -44.39, -43.81, -42.82, -42.72, -42.37, -41.92, -41.25, -40.95, -39.13, -38.71, -38.28, -37.88, -36.82, -36.6, -35.9, -35.69, -35.33, -35.2, -35.17, -34.39, -33.91, -33.87, -33.58, -32.35, -31.8, -31.18, -31.1, -30.51, -30.18, -29.71, -29.56, -28.31, -27.93, -27.78, -27.64, -27.56, -27.26, -26.4, -25.96, -25.94, -25.51, -25.15, -25.06, -24.9, -24.48, -24.45, -24.16, -24.0, -23.81, -23.78, -23.28, -23.
# ...

# %%
per = op.get_per("2017/12/1")

# %%
len(per)
# Out:
# 3119

# %%
with open("data//per.txt","w") as f:
    for d in per_list:
        print(d, file=f)

# %% [markdown]
# ## プロット

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(0,100))

# %%
len(list(filter(lambda x: x<3, per_list)))
# Out:
# 6

# %%
distribution = list(map(lambda th: len(list(filter(lambda per: per < th, per_list))), x))

# %%
distribution
# Out:
# [0,
#  0,
#  3,
#  6,
#  16,
#  39,
#  68,
#  126,
#  205,
#  301,
#  422,
#  536,
#  678,
#  797,
#  924,
#  1054,
#  1180,
#  1295,
#  1408,
#  1501,
#  1600,
#  1678,
#  1764,
#  1840,
#  1911,
#  1975,
#  2021,
#  2061,
#  2112,
#  2149,
#  2185,
#  2220,
#  2238,
#  2266,
#  2296,
#  2316,
#  2338,
#  2356,
#  2373,
#  2395,
#  2403,
#  2416,
#  2432,
#  2446,
#  2461,
#  2472,
#  2477,
#  2489,
#  2500,
#  2509,
#  2523,
#  2537,
#  2546,
#  2553,
#  2560,
#  2566,
#  2573,
#  2578,
#  2582,
#  2591,
#  2597,
#  2607,
#  2611,
#  2616,
#  2621,
#  2624,
#  2631,
#  2634,
#  2635,
#  2638,
#  2643,
#  2647,
#  2649,
#  2653,
#  2659,
#  2664,
#  2669,
#  2671,
#  2672,
#  2672,
#  2674,
#  2676,
#  2680,
#  2680,
#  2681,
#  2682,
#  2682,
#  2685,
#  2690,
#  2693,
#  2698,
#  2699,
#  2700,
#  2702,
#  2706,
#  2711,
#  2713,
#  2715,
#  2716,
#  2716]

# %%
plt.scatter(x, distribution)
plt.show()
